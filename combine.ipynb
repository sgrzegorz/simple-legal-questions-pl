# %%
import pandas as pd

# %%
# !ls
# Out:
# answers_kosciolek.csv	       questions_narogm.csv
# questions-all.csv	       questions_przemyslaw_jablecki.csv
# questions_anna_swiadek.csv     questions_tomekzaw.csv
# questions_Arkadiusz_Kraus.csv  questions_wiktor_pawlowski.csv
# questions_dmajchrowski.csv     README.md
# questions_jgluza.csv	       Untitled.ipynb
# questions_lukasz_kowalski.csv

# %%
f1 = pd.read_csv("answers_kosciolek.csv")
f1['has_answer'] = True
f1.describe()
f1
# Out:
#            passage_id                                           question  \
# 0    1997_553_345.txt  Czy żołnierz, który dopuszcza się czynnej napa...
# 1     2004_177_21.txt         Z ilu osób składa się komisja przetargowa?
# 2    1996_465_111.txt  Do jakiej wysokości za zobowiązania spółki odp...
# 3     1994_591_35.txt  Kiedy ustala się wartość majątku obrotowego, k...
# 4    2001_1441_74.txt  Jakiej karze podlega armator, który wykonuje r...
# 5    2002_1689_31.txt  Kogo zwalnia się od akcyzy według zasady wzaje...
# 6    2001_1353_12.txt  Czy żołnierze przy wykonaniu czynności służbow...
# 7     1994_592_85.txt         Ile budżetów ma miasto na prawach powiatu?
# 8    2001_1353_40.txt  Czy żołnierze Żandarmerii Wojskowej mogą uni...
# 9     1997_735_44.txt  W jakim przypadku policja może dokonać przeszu...
# 10    1997_884_31.txt  Jakim warunkom powinny odpowiadać przekazywane...
# 11    1997_348_56.txt  Jakiej karze podlega osoba, która nie stosuje ...
# ...

# %%
f2 = pd.read_csv("questions-all.csv")
f2['has_answer'] = True
f2
# Out:
#        passage_id                                           question  \
# 0     2001_1319_1  Kto ma zgodę na dokonanie ratyfikacji Umowy mi...
# 1      2001_634_6  Czego zakazuje się wykrzysytwać do żywienia lu...
# 2      1999_548_5  Kto ponosi odpowiedzialność w razie wyrządzeni...
# 3    2004_880_149             Jakie zwierzęta podlegają rejestracji?
# 4    2001_1382_15  Pod jakim warunkiem zezwolenia na prowadzenie ...
# 5   2003_1750_117  W jakim zakresie stosuje się również te przepisy?
# 6    2000_1319_87  Czy podmiotowi przysługuje prawo do wniesienia...
# 7     1998_1125_2  Czy osoba, która cieszy się nieposzlakowaną op...
# 8     1997_539_19  Czy w każdej gminie znajduje się wojewódzka bi...
# 9     1995_713_24                        Co to obwód łowiecki leśny?
# 10     1997_777_8      Na co przeznacza się Środki Funduszu Rozwoju?
# 11   1997_555_612  Co robi się z każdorazowym wypadkiem zastosowa...
# 12   1999_930_157  Czy udział prokuratora w rozprawie wyłącza obo...
# ...

# %%
f3 = pd.read_csv("questions_anna_swiadek.csv")
f3
# Out:
#        passage_id                                           question  \
# 0     2001_1441_6    Na ile wydawna jest licencja na statek rybacki?
# 1        2000_6_1  Jakie zadania wykonują jednostki podległe Szef...
# 2     1997_31_118  Co grozi za wprowadzanie do obrotu mięsa niezd...
# 3      2004_624_5  Kiedy Skarb Państwa może rozwiązać spółkę celową?
# 4     1997_449_34  Czy funkcjonariusze Inspekcji Celnej mogą być ...
# ..            ...                                                ...
# 154   2000_985_33                    Kogo można nazwać cudzoziemcem?
# 155  2001_1371_72  Kto powinien dokonywać badań ciała, jeżeli moż...
# 156   2004_287_28  Kto powinien dokonywać badań ciała, jeżeli moż...
# 157   1997_555_16  Kto powinien dokonywać badań ciała, jeżeli moż...
# 158  1997_553_157  Kto powinien dokonywać badań ciała, jeżeli moż...
#
#      has_answer                                            passage
# 0          True  1. Licencję, na wniosek armatora, wydaje minis...
# ...

# %%
f4 = pd.read_csv("questions_Arkadiusz_Kraus.csv", sep=";")
f4['has_answer'] = True
f4
# Out:
#                                              question            passage_id  \
# 0   Kto jest ubezpieczonymi na podstawie przepisów...    2001_906.txt:Art.2
# 1   Na czyj wniosek Rada Ministrów ustala cenę min...    2001_83.txt:Art.11
# 2   Do czego zobowiązane są organy Państwowej Stra...  2001_627.txt:Art.268
# 3   Co ogłasza się w Biuletynie Zamówień Publicznych?   1994_344.txt:Art.11
# 4                         Co to jest dzień bilansowy?    1994_591.txt:Art.3
# ..                                                ...                   ...
# 59  Kto opracowuje plan zapewnienia bezpieczeństwa...    2004_285.txt:Art.1
# 60                 Kiedy wygasa członkostwo w Radzie?   1996_402.txt:Art.10
# 61                 Kiedy wygasa członkostwo w Radzie?    1997_24.txt:Art.19
# 62                 Kiedy wygasa członkostwo w Radzie?  2003_1834.txt:Art.10
# 63                      Co to jest margines dumpingu?  2001_1352.txt:Art.16
#
# ...

# %%
f5 = pd.read_csv("questions_dmajchrowski.csv")
f5['has_answer'] = f5['is_negative'].apply(lambda x: x == 0)
f5 = f5.drop(columns=['is_negative'])
f5
# Out:
#                passage_id                                           question  \
# 0    1997_553.txt:Art.249  Co grozi za podglądanie głosów innych osób pod...
# 1    1997_553.txt:Art.250  Co grozi za podglądanie głosów innych osób pod...
# 2    1997_553.txt:Art.251  Co grozi za podglądanie głosów innych osób pod...
# 3     2001_627.txt:Art.83  Co należy zrobić, tworząc standard jakości śro...
# 4     1997_926.txt:Art.51                    Co to jest zaległość podatkowa?
# ..                    ...                                                ...
# 163   2001_628.txt:Art.55  O co muszą zadbać osoby, które wytwarzają odpa...
# 164  1997_933.txt:Art.137    Za co odpowiada fundusz inwestycyjny zamknięty?
# 165    1997_933.txt:Art.5    Za co odpowiada fundusz inwestycyjny zamknięty?
# 166  2004_1205.txt:Art.19    Za co odpowiada fundusz inwestycyjny zamknięty?
# 167  2004_1205.txt:Art.24    Za co odpowiada fundusz inwestycyjny zamknięty?
#
# ...

# %%
f6 = pd.read_csv("questions_jgluza.csv", sep=";")
f6['has_answer'] = True
f6
# Out:
#                                              question     passage_id  \
# 0   Jakie instytucje są organami dochodzenia w spr...   1999_930_133
# 1   Jakiej zdolności nie można pozbawiać zwierząt ...    1997_724_31
# 2   Kiedy emisję obligacji uważa się za niedoszłą ...    1995_420_13
# 3   Jak długo trwa obowiązkowa kwarantanna dla osó...   2001_1384_27
# 4   Ile razy w roku przysługuje żołnierzowi zawodo...   2003_1750_87
# 5   Jaki procent uprawnionych do głosowania musi w...    2000_985_55
# 6                       Kto wykonuje funkcje konsula?   2001_1403_21
# 7   Ile co najmniej wynosi okres przestawiania cho...    2001_452_18
# 8   Kto prowadzi rejestr zezwoleń na prowadzenie a...  2001_1381_107
# 9   Co zawiera informacja o osobie, sporządzona na...    2000_580_20
# 10  Od jakiego dnia każdego roku nalicza się podwy...   1998_1125_13
# 11  Jakie są zadania gmin w ramach prac związanych...      1995_5_11
# 12  Co obowiązany jest mieć przy sobie kierowca po...   2001_1371_87
# ...

# %%
f7 = pd.read_csv("questions_lukasz_kowalski.csv", sep=";")
f7['has_answer'] = True
f7
# Out:
#                                            passage_id  \
# 0                              1994_195.txt-Art. 219.
# 1                              1997_555.txt-Art. 237.
# 2                               1995_420.txt-Art. 31.
# 3                                1998_577.txt-Art. 7.
# 4   2000_1186.txt-Art. 14. 1. Dziennik zawiera chr...
# ..                                                ...
# 66                              1997_468.txt-Art. 57.
# 67                              1997_593.txt-Art. 24.
# 68  2004_868.txt-Art. 175b. Prezes sądu apelacyjne...
# 69                              1994_195.txt-Art. 79.
# 70                               2001_19.txt-Art. 40.
#
#                                              question  \
# 0             Co jeśli dwie topografie są identyczne?
# 1   Kto posiada prawo odtwarzania zapisów telefoni...
# 2           Jaki bank może pełnić rolę reprezentanta?
# 3                          Jakie role pełni wojewoda?
# ...

# %%
f8 = pd.read_csv("questions_narogm.csv", sep=";", names=["passage_id", "question", "passage"])
f8['has_answer'] = True
f8
# Out:
#              passage_id                                           question  \
# 0   1994_195.txt_Art.10  Gdzie należy dokonać sprawdzenia, czy spełnion...
# 1   1994_344.txt_Art.10                    Kto powołuje członków Kolegium?
# 2    1994_369.txt_Art.8  Kto powołuje prezesa zarządu banku spółdzielcz...
# 3    1994_591.txt_Art.9   W jakiej walucie prowadzi się księgi rachunkowe?
# 4    1994_627.txt_Art.2  Przez kogo są wydawane przepisy techniczno-bud...
# 5      1995_1.txt_Art.3                  Komu podlega Krajowy Urząd Pracy?
# 6     1995_59.txt_Art.1              Komu podlega Najwyższa Izba Kontroli?
# 7    1995_368.txt_Art.3  Kto ustala strukturę organizacyjną Naczelnego ...
# 8    1995_436.txt_Art.1  Kto tworzy lokalną wspólnotę samorządową powiatu?
# 9    1995_439.txt_Art.8  Jakie informacje nie mogą być zbierane w badan...
# 10   1995_713.txt_Art.6  Kto jest naczelnym organem administracji rządo...
# ...

# %%
f9 = pd.read_csv("questions_przemyslaw_jablecki.csv", sep=";")
f9['has_answer'] = True
f9['passage'] = f9['content']
f9['passage_id'] = f9['id']
f9 = f9.drop(columns=['content', 'id'])
f9
# Out:
#                                              question  has_answer  \
# 0                             Kto to jest Prezes URE?        True
# 1            Czym jest uchwała budżetowa województwa?        True
# 2                           Czym jest spis kontrolny?        True
# 3          Do jakiego leczenia ma prawo ubezpieczony?        True
# 4   Co jest podstawą prawną do egzekucji uposażeni...        True
# 5   Kto jest naczelnym organem administracji w spr...        True
# 6   Czyja opinia może być konieczna do rozdzieleni...        True
# 7              Co można finansować z budżetu państwa?        True
# 8   Jaki jest przykładowy organ pomocniczy Delegat...        True
# 9   Jakie warunki muszą być spełnione aby żołnierz...        True
# 10  Kiedy nie stosuje się postępowania uproszczonego?        True
# 11  Kto zapewnia przestrzeganie zasad higieny w pr...        True
# 12  Czy ogrody zoologiczne są zobowiązane do zgłos...        True
# ...

# %%
f10 = pd.read_csv("questions_tomekzaw.csv")
f10['has_answer'] = True
f10
# Out:
#        passage_id                                           question  \
# 0     2004_167_32  Ile wynosi przeciętne wynagrodzenie brutto pro...
# 1    1996_465_305  Jakie dodatkowe oznaczenie powinna zawierać fi...
# 2    1996_465_127  Jakie dodatkowe oznaczenie powinna zawierać fi...
# 3    1996_465_160  Jakie dodatkowe oznaczenie powinna zawierać fi...
# 4     1996_465_24  Jakie dodatkowe oznaczenie powinna zawierać fi...
# 5     1997_739_97  Kto określa tryb udzielania pomocy przez organ...
# 6    1997_555_443  W jakim przypadku można wydać orzeczenie surow...
# 7     1998_717_86  W jakim przypadku można wydać orzeczenie surow...
# 8     1995_29_163  Jakiej karze podlega osoba, która w lesie rozg...
# 9       1995_1_29  O ile można maksymalnie pomniejszyć świadczeni...
# 10    1994_516_23  O ile można maksymalnie pomniejszyć świadczeni...
# 11   1997_555_625  Jakie koszty sądowe pobiera się od żołnierza z...
# 12   1997_553_238  Jakiej karze podlega ten, kto zawiadamia o prz...
# ...

# %%
f11 = pd.read_csv("questions_wiktor_pawlowski.csv", sep=";", names=["passage_id", "question", "passage"])
f11['has_answer'] = True
f11
# Out:
#                passage_id                                           question  \
# 0       1997_31.txt:Art.3  Czy Minister Zdrowia może określić inne chorob...
# 1    1997_926.txt:Art.304  Czy naczelnicy urzędów skarbowych składają Min...
# 2    1996_465.txt:Art.201                  Czy zarząd może być jednoosobowy?
# 3        1995_5.txt:Art.8  Czy osoby wykonujące prace związane z przygoto...
# 4    2004_1532.txt:Art.18  Jakiej komisji Minister właściwy do spraw admi...
# 5    1997_553.txt:Art.352  Jakiej karze podlega żołnierz, który znęca się...
# 6     1997_739.txt:Art.66  Czy dane osobowe cudzoziemców, którym nadano s...
# 7    1997_553.txt:Art.222  Czy naruszenie nietykalności cielesnej funkcjo...
# 8    2001_1071.txt:Art.10  Czy kuratorowi zawodowemu przysługuje prawo do...
# 9   2001_1545.txt:Art.232  Czy za uratowanie frachtu oraz opłat za przewó...
# 10   1996_465.txt:Art.556        Co jest wymagane do przekształcenia spółki?
# ...

# %%
import re
joined = pd.concat([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11], ignore_index=True)
joined['passage'] = joined['passage'].apply(lambda x: re.sub("\n", " ", x))
joined.to_csv('combined.csv', index=False)

# %%
# !head combined.csv
# Out:
# passage_id,question,passage,has_answer
# 1997_553_345.txt,"Czy żołnierz, który dopuszcza się czynnej napaści na przełożonego podlega karze pozbawienia wolności?","Art. 345. § 1. Żołnierz, który dopuszcza się czynnej napaści na przełożonego, podlega karze aresztu wojskowego albo pozbawienia wolności do lat 3. § 2. Jeżeli sprawca dopuszcza się czynnej napaści w związku z pełnieniem przez przełożonego obowiązków służbowych albo wspólnie z innymi żołnierzami lub w obecności zebranych żołnierzy, podlega karze pozbawienia wolności od 6 miesięcy do lat 8. § 3. Jeżeli sprawca czynu określonego w § 1 lub 2 używa broni, noża lub innego podobnie niebezpiecznego przedmiotu, podlega karze pozbawienia wolności od roku do lat 10. § 4. Karze przewidzianej w § 3 podlega sprawca czynu określonego w § 1 lub 2, jeżeli jego następstwem jest skutek określony w art. 156 lub 157 § 1.",True
# ...
